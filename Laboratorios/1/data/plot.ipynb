# %%
import pandas as pd
import numpy as np

raio_fixo = pd.read_csv('raio-fixo.csv')
angulo_fixo = pd.read_csv('angulo-fixo.csv')
lados_fixo = pd.read_csv('lados-fixo.csv')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(raio_fixo["Ângulo"], raio_fixo["Lados"], raio_fixo["Tempo (ms)"], zdir='z', s=20, c=raio_fixo["Tempo (ms)"], edgecolors='black', depthshade=False, cmap="plasma")

ax.set_xlabel('Ângulo')
ax.set_ylabel('Lados')
ax.set_zlabel('Tempo (ms)')
# Out:
# Text(0.5, 0, 'Tempo (ms)')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(angulo_fixo["Raio"], angulo_fixo["Lados"], angulo_fixo["Tempo (ms)"], zdir='z', s=20, c=angulo_fixo["Tempo (ms)"], edgecolors='black', depthshade=False, cmap="plasma")

ax.set_xlabel('Raio')
ax.set_ylabel('Lados')
ax.set_zlabel('Tempo (ms)')
# Out:
# Text(0.5, 0, 'Tempo (ms)')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(lados_fixo["Ângulo"], lados_fixo["Raio"], lados_fixo["Tempo (ms)"], zdir='z', s=20, c=lados_fixo["Tempo (ms)"], edgecolors='black', depthshade=False, cmap="plasma")

ax.set_xlabel('Ângulo')
ax.set_ylabel('Raio')
ax.set_zlabel('Tempo (ms)')
# Out:
# Text(0.5, 0, 'Tempo (ms)')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(angulo_fixo["Lados"], angulo_fixo["Raio"],  angulo_fixo["Tempo (ms)"], zdir="z", marker='o', linewidth=1, markersize=2)

#ax.set_xlabel('Ângulo')
#ax.set_ylabel('Raio')
#ax.set_zlabel('Tempo (ms)')
